# %% [markdown]
# Name-Vidhi Rathod

# %%
#checking the version 
import sys
assert sys.version_info >= (3,5)

# %%
#checking the version required >= 0.20
import sklearn
assert sklearn.__version__ >= "0.20"

# %%
#importing the libraries 
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sns
import time
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import matplotlib as mp
#       5 import seaborn as sns
#       6 import time
#
# File c:\Users\vidhi\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:214
#     209         if parse_version(module.__version__) < parse_version(minver):
#     210             raise ImportError(f"Matplotlib requires {modname}>={minver}; "
#     211                               f"you have {module.__version__}")
# --> 214 _check_versions()
#     217 # The decorator ensures this always returns the same handler (and it is only
#     218 # attached once).
#     219 @functools.lru_cache()
#     220 def _ensure_handler():
#
# File c:\Users\vidhi\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:199, in _check_versions()
#     195 def _check_versions():
#     196
#     197     # Quickfix to ensure Microsoft Visual C++ redistributable
#     198     # DLLs are loaded before importing kiwisolver
# --> 199     from . import ft2font
#     201     for modname, minver in [
#     202             ("cycler", "0.10"),
#     203             ("dateutil", "2.7"),
#    (...)
#     206             ("pyparsing", "2.2.1"),
#     207     ]:
#     208         module = importlib.import_module(modname)
#
# KeyboardInterrupt:

# %%
# To plot  figures directly within Jupyter
# %matplotlib inline
import matplotlib as mpl
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %% [markdown]
# Data encoding
# Correlation columns
# Data cleaning: age,

# %%
obesityDf = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
obesityDf.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
# creating new column for BMI
df = obesityDf.assign(BMI= obesityDf['Weight'] / obesityDf['Height'] * obesityDf['Height'])
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad   BMI
# 0  Public_Transportation        Normal_Weight  64.0
# 1  Public_Transportation        Normal_Weight  56.0
# 2  Public_Transportation        Normal_Weight  77.0
# 3                Walking   Overweight_Level_I  87.0
# 4  Public_Transportation  Overweight_Level_II  89.8

# %%
#Data Encoding
df['Gender']= df.Gender.astype('category').cat.codes
df['family_history_with_overweight']= df.family_history_with_overweight.astype('category').cat.codes
df['FAVC']= df.FAVC.astype('category').cat.codes
df['CAEC']= df.CAEC.astype('category').cat.codes
df['SCC']= df.SCC.astype('category').cat.codes
df['CALC']= df.CALC.astype('category').cat.codes
df['MTRANS']= df.MTRANS.astype('category').cat.codes
df['NObeyesdad']= df.NObeyesdad.astype('category').cat.codes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Data Encoding
# ----> 2 df['Gender']= df.Gender.astype('category').cat.codes
#       3 df['family_history_with_overweight']= df.family_history_with_overweight.astype('category').cat.codes
#       4 df['FAVC']= df.FAVC.astype('category').cat.codes
#
# NameError: name 'df' is not defined

# %%
#calculating mean median and standard deviation
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE          BMI
# count  2111.000000  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866    86.586058
# std       0.612953     0.850592     0.608927    26.191172
# min       1.000000     0.000000     0.000000    39.000000
# 25%       1.584812     0.124505     0.000000    65.473343
# 50%       2.000000     1.000000     0.625350    83.000000
# 75%       2.477420     1.666678     1.000000   107.430682
# max       3.000000     3.000000     2.000000   173.000000

# %%
#plotting boxplot
df.boxplot()
# Out:
# <AxesSubplot: >

# %%
features=['Age', 'Height', 'Weight', 'FCVC','NCP','CH2O', 'FAF','TUE', 'BMI']
sns.set()
sns.pairplot(df[features])
